# %% [markdown]
# # Histograma

# %% [markdown]
# Cuanto mide una moneda de 2 pesos?

# %%
x = [2.4,2.5,2.5,2.4,2.4,2.4,2.5,2.4,2.4,2.4,2.5,2.5,2.6,2.5,2.6,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.4,2.3,2.3,2.3,2.47,2.47,2.47,2.4,2.4,2.4,2.4,2.4,2.4,2.2,2.3,2.2]
# Out:
# 46-element Vector{Float64}:
#  2.4
#  2.5
#  2.5
#  2.4
#  2.4
#  2.4
#  2.5
#  2.4
#  2.4
#  2.4
#  2.5
#  2.5
#  2.6
#  ⋮
#  2.47
#  2.47
#  2.47
#  2.4
#  2.4
#  2.4
#  2.4
#  2.4
#  2.4
#  2.2
#  2.3
#  2.2

# %% [markdown]
# Poner los datos asi es medio un bajon, más adelante vamos a aprender a leer los datos de un archivo

# %%
using Plots

# %%
histogram(x,bins=6)

# %% [markdown]
# Ahora vamos a leer los datos de una tabla en formato CSV

# %%
using CSV

# %%
using DataFrames

# %%
data = DataFrame(CSV.File("mediciones_tp1_fisica1.csv"));

# %%
describe(data)
# Out:
# 4×7 DataFrame
#  Row │ variable  mean      min   median   max    nmissing  eltype
#      │ Symbol    Float64   Real  Float64  Real   Int64     DataType
# ─────┼──────────────────────────────────────────────────────────────
#    1 │ Medicion  61.5      1        61.5  122           0  Int64
#    2 │ diametro   2.33148  2.18      2.3    2.6         0  Float64
#    3 │ Tipo       1.85246  1         2.0    5           0  Int64
#    4 │ Grupo      4.95082  1         5.0    9           0  Int64

# %%
histogram(data.diametro,label="diametro moneda",bins=5)

# %%
boxplot(data.diametro)
# Out:
# ┌ Warning: Keyword argument hover not supported with Plots.GRBackend().  Choose from: Set([:top_margin, :group, :inset_subplots, :background_color, :ytickfontsize, :yforeground_color_text, :yguidefontcolor, :tickfontfamily, :show_empty_bins, :seriesalpha, :seriescolor, :ztick_direction, :xgrid, :ygridalpha, :zlims, :xtick_direction, :colorbar, :legend_font_family, :zflip, :ticks, :linealpha, :overwrite_figure, :arrow, :xguidefonthalign, :normalize, :linestyle, :xtickfontvalign, :xflip, :zgrid, :fillcolor, :ygrid, :bar_width, :colorbar_scale, :background_color_inside, :zguidefonthalign, :bins, :zguide, :zforeground_color_text, :legend_font_valign, :yscale, :legend_font_color, :weights, :xgridalpha, :ygridstyle, :clims, :xtickfontcolor, :fill_z, :xguide, :markershape, :background_color_subplot, :ztickfontfamily, :fillalpha, :markerstrokewidth, :tick_direction, :xguidefontvalign, :xguidefontfamily, :gridlinewidth, :foreground_color_subplot, :xgridlinewidth, :yguidefontsize, :foreground_
# ...

# %% [markdown]
# kjjj horrible lo que salió. Despues veo como arreglarlo
